# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['a','b','c','d','e'],['w','x','y','z'])

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
#conditional selection

# %%
bool_df = df >0

# %%
bool_df
# Out:
#        w      x      y      z
# a   True   True   True   True
# b   True  False  False   True
# c  False   True   True  False
# d   True  False  False   True
# e   True   True   True   True

# %%
df[bool_df]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118       NaN       NaN  0.605965
# c       NaN  0.740122  0.528813       NaN
# d  0.188695       NaN       NaN  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df['w'] >0
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# Name: w, dtype: bool

# %%
df[df['w']>0]
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[df['z']<0]
# Out:
#           w         x         y         z
# c -2.018168  0.740122  0.528813 -0.589001

# %%
resultdf = df[df['w']>0]

# %%
resultdf
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
resultdf['x']
# Out:
# a    0.628133
# b   -0.319318
# d   -0.758872
# e    1.978757
# Name: x, dtype: float64

# %%
df[df['w']>0]['x']
# Out:
# a    0.628133
# b   -0.319318
# d   -0.758872
# e    1.978757
# Name: x, dtype: float64

# %%
df[df['w']>0][['y','x']]
# Out:
#           y         x
# a  0.907969  0.628133
# b -0.848077 -0.319318
# d -0.933237 -0.758872
# e  2.605967  1.978757

# %%
df[(df['w']>0) & (df['y']>1)] #instead of and use &
# Out:
#           w         x         y         z
# e  0.190794  1.978757  2.605967  0.683509

# %%
df[(df['w']>0) | (df['y']>1)] #instead of or use |
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index() #inplace=True to make it permanent
# Out:
#   index         w         x         y         z
# 0     a  2.706850  0.628133  0.907969  0.503826
# 1     b  0.651118 -0.319318 -0.848077  0.605965
# 2     c -2.018168  0.740122  0.528813 -0.589001
# 3     d  0.188695 -0.758872 -0.933237  0.955057
# 4     e  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z
# a  2.706850  0.628133  0.907969  0.503826
# b  0.651118 -0.319318 -0.848077  0.605965
# c -2.018168  0.740122  0.528813 -0.589001
# d  0.188695 -0.758872 -0.933237  0.955057
# e  0.190794  1.978757  2.605967  0.683509

# %%
newind = "CA NY NJ TX MI".split()

# %%
newind
# Out:
# ['CA', 'NY', 'NJ', 'TX', 'MI']

# %%
df["states"] = newind # to add new column to the dataframe

# %%
df
# Out:
#           w         x         y         z states
# a  2.706850  0.628133  0.907969  0.503826     CA
# b  0.651118 -0.319318 -0.848077  0.605965     NY
# c -2.018168  0.740122  0.528813 -0.589001     NJ
# d  0.188695 -0.758872 -0.933237  0.955057     TX
# e  0.190794  1.978757  2.605967  0.683509     MI

# %%
df.reset_index()
# Out:
#   index         w         x         y         z states
# 0     a  2.706850  0.628133  0.907969  0.503826     CA
# 1     b  0.651118 -0.319318 -0.848077  0.605965     NY
# 2     c -2.018168  0.740122  0.528813 -0.589001     NJ
# 3     d  0.188695 -0.758872 -0.933237  0.955057     TX
# 4     e  0.190794  1.978757  2.605967  0.683509     MI

# %%
df.set_index("states") #to make a column into index 
                        #inplace = True to make it permanent
# Out:
#                w         x         y         z
# states
# CA      2.706850  0.628133  0.907969  0.503826
# NY      0.651118 -0.319318 -0.848077  0.605965
# NJ     -2.018168  0.740122  0.528813 -0.589001
# TX      0.188695 -0.758872 -0.933237  0.955057
# MI      0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           w         x         y         z states
# a  2.706850  0.628133  0.907969  0.503826     CA
# b  0.651118 -0.319318 -0.848077  0.605965     NY
# c -2.018168  0.740122  0.528813 -0.589001     NJ
# d  0.188695 -0.758872 -0.933237  0.955057     TX
# e  0.190794  1.978757  2.605967  0.683509     MI
